# %% [markdown]
# # API Usage

# %%
# %matplotlib inline
import skimage.io as io
import skimage.transform as transform
import matplotlib.pyplot as plt

example = io.imread('examples/face.jpg')
plt.imshow(example)
plt.axis('off')
plt.show()

# %%
from get_keypoints import *

keypoints = get_raw_keypoints(example)
keypoints.shape
# Out:
# torch.Size([1, 29, 64, 64])

# %%
result = transform_img_with_keypoints(example, keypoints_dataset='WFLW')

result = transform.resize(result, example.shape, anti_aliasing=True)

# %%
dpi = 80
height, width, nbands = example.shape
figsize = width / float(dpi), height / float(dpi)

fig = plt.figure(figsize=figsize)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')
ax.imshow(result, interpolation='nearest')

fig.savefig('examples/keypoints.png', dpi=dpi, transparent=True)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Keypoints labels

# %%
import json

with open('wflw_landmark_labels.json', 'r') as fp:
    data = json.load(fp)
data
# Out:
# {'0': 'cheekbones_left_ear',
#  '1': 'cheekbones_left_ear',
#  '2': 'cheekbones_left_ear',
#  '3': 'cheekbones_left_ear',
#  '4': 'cheekbones_left_ear',
#  '5': 'cheekbones_left_ear',
#  '6': 'cheekbones_left_main',
#  '7': 'cheekbones_left_main',
#  '8': 'cheekbones_left_main',
#  '9': 'cheekbones_left_main',
#  '10': 'cheekbones_left_main',
#  '11': 'cheekbones_left_chin',
#  '12': 'cheekbones_left_chin',
#  '13': 'cheekbones_left_chin',
#  '14': 'cheekbones_left_chin',
#  '15': 'cheekbones_left_chin',
#  '16': 'cheekbones_tip',
#  '17': 'cheekbones_right_chin',
#  '18': 'cheekbones_right_chin',
#  '19': 'cheekbones_right_chin',
#  '20': 'cheekbones_right_chin',
#  '21': 'cheekbones_right_chin',
#  '22': 'cheekbones_right_main',
#  '23': 'cheekbones_right_main',
#  '24': 'cheekbones_right_main',
#  '25': 'cheekbones_right_main',
#  '26': 'cheekbones_right_main',
#  '27': 'cheekbones_right_ear',
#  '28': 'cheekbones_right_ear',
#  '29': 'cheekbones_right_ear',
# ...

# %%
x = torch.tensor([
    [1, 2],
    [4, 1],
    [7, 9]
])
torch.argmax(x)
# Out:
# tensor(5)

# %%
t =
